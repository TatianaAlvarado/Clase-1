# %% [markdown]
# <a href="https://colab.research.google.com/github/TatianaAlvarado/Clase-1/blob/main/DRUGS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries
import numpy as np
import pandas as pd

# %%
#  Save the path o the file 
p ='/content/DRUGS.xlsx'

# Read the file
d = pd.read_excel(p)

#Chek
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454 entries, 0 to 453
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             454 non-null    object
#  1   Country/Territory  454 non-null    object
#  2   DrugGroup          454 non-null    object
#  3   unit               454 non-null    object
#  4   KgEquivalent       454 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 17.9+ KB

# %%
d.head()
# Out:
#    Region Country/Territory  \
# 0    Asia       Afghanistan
# 1  Africa           Algeria
# 2  Africa           Algeria
# 3  Africa           Algeria
# 4  Africa           Algeria
#
#                                            DrugGroup       unit  KgEquivalent
# 0  Cannabis-type drugs (excluding synthetic canna...  Kilograms    422658.000
# 1  Cannabis-type drugs (excluding synthetic canna...  Kilograms        16.496
# 2  Cannabis-type drugs (excluding synthetic canna...  Kilograms     88702.581
# 3  Cannabis-type drugs (excluding synthetic canna...  Kilograms         4.547
# 4                                       Cocaine-type  Kilograms        32.353

# %%
d.tail()
# Out:
#      Region Country/Territory  \
# 449  Africa            Zambia
# 450  Africa            Zambia
# 451  Africa            Zambia
# 452  Africa          Zimbabwe
# 453  Africa          Zimbabwe
#
#                                              DrugGroup       unit  \
# 449  Cannabis-type drugs (excluding synthetic canna...      Grams
# 450  Cannabis-type drugs (excluding synthetic canna...      Grams
# 451                                       Cocaine-type      Grams
# 452  Cannabis-type drugs (excluding synthetic canna...  Kilograms
# 453                                       Cocaine-type  Kilograms
#
#      KgEquivalent
# 449       2.41400
# 450      51.52249
# 451       0.47044
# 452     338.00000
# 453       1.30000
