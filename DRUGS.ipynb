# %% [markdown]
# <a href="https://colab.research.google.com/github/TatianaAlvarado/Clase-1/blob/main/DRUGS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries
import numpy as np
import pandas as pd
import plotly.express as px

# %%
#  Save the path o the file 
p ='/content/DRUGS.xlsx'

# Read the file
d = pd.read_excel(p)

#Chek
d.info()

# %%
d.head()
# Out:
#    Region    Territory                                          DrugGroup  \
# 0    Asia  Afghanistan  Cannabis-type drugs (excluding synthetic canna...
# 1  Africa      Algeria  Cannabis-type drugs (excluding synthetic canna...
# 2  Africa      Algeria  Cannabis-type drugs (excluding synthetic canna...
# 3  Africa      Algeria  Cannabis-type drugs (excluding synthetic canna...
# 4  Africa      Algeria                                       Cocaine-type
#
#         unit  KgEquivalent
# 0  Kilograms    422658.000
# 1  Kilograms        16.496
# 2  Kilograms     88702.581
# 3  Kilograms         4.547
# 4  Kilograms        32.353

# %%
d.head(15)
# Out:
#       Region    Territory                                          DrugGroup  \
# 0       Asia  Afghanistan  Cannabis-type drugs (excluding synthetic canna...
# 1     Africa      Algeria  Cannabis-type drugs (excluding synthetic canna...
# 2     Africa      Algeria  Cannabis-type drugs (excluding synthetic canna...
# 3     Africa      Algeria  Cannabis-type drugs (excluding synthetic canna...
# 4     Africa      Algeria                                       Cocaine-type
# 5     Europe      Andorra  Cannabis-type drugs (excluding synthetic canna...
# 6     Europe      Andorra  Cannabis-type drugs (excluding synthetic canna...
# 7     Europe      Andorra                                       Cocaine-type
# 8   Americas    Argentina  Cannabis-type drugs (excluding synthetic canna...
# 9   Americas    Argentina  Cannabis-type drugs (excluding synthetic canna...
# 10  Americas    Argentina  Cannabis-type drugs (excluding synthetic canna...
# 11  Americas    Argentina  Cannabis-type drugs (excluding synthetic canna...
# 12  Americas    Argentina  Cannabis-type drugs (excluding synthetic canna...
# 13  Americas    Argentina  Cannabis-type drugs (excluding synthetic canna...
# 14  Americas    Argentina  Cannabis-type drugs (excluding synthetic canna...
#
#          unit  KgEquivalent
# 0   Kilograms  422658.00000
# 1   Kilograms      16.49600
# 2   Kilograms   88702.58100
# 3   Kilograms       4.54700
# 4   Kilograms      32.35300
# 5       Grams       5.59700
# 6       Grams       0.70200
# 7       Grams       0.17200
# 8   Kilograms  236624.07920
# 9   Kilograms       0.28800
# 10  Kilograms    2026.85146
# 11  Kilograms       4.52920
# 12  Kilograms       0.97041
# 13  Kilograms       0.22705
# 14  Kilograms    1631.65185

# %%
# Me sirve para mirar si el archivo tiene algo raro
d.tail()
# Out:
#      Region Territory                                          DrugGroup  \
# 449  Africa    Zambia  Cannabis-type drugs (excluding synthetic canna...
# 450  Africa    Zambia  Cannabis-type drugs (excluding synthetic canna...
# 451  Africa    Zambia                                       Cocaine-type
# 452  Africa  Zimbabwe  Cannabis-type drugs (excluding synthetic canna...
# 453  Africa  Zimbabwe                                       Cocaine-type
#
#           unit  KgEquivalent
# 449      Grams       2.41400
# 450      Grams      51.52249
# 451      Grams       0.47044
# 452  Kilograms     338.00000
# 453  Kilograms       1.30000

# %% [markdown]
# # **3. Cleaning**

# %% [markdown]
# ## Column Names

# %%
# Change time for year
d.rename(columns = {'Country/Territory': 'Territory'}, inplace = True)

# Check
d.head()

# %% [markdown]
# # **Dlete Columns**

# %%
d = d.drop(columns = ['unit'])
d.head()
# Out:
#    Region    Territory                                          DrugGroup  \
# 0    Asia  Afghanistan  Cannabis-type drugs (excluding synthetic canna...
# 1  Africa      Algeria  Cannabis-type drugs (excluding synthetic canna...
# 2  Africa      Algeria  Cannabis-type drugs (excluding synthetic canna...
# 3  Africa      Algeria  Cannabis-type drugs (excluding synthetic canna...
# 4  Africa      Algeria                                       Cocaine-type
#
#    KgEquivalent
# 0    422658.000
# 1        16.496
# 2     88702.581
# 3         4.547
# 4        32.353

# %% [markdown]
# # **A few more things**

# %%
# (Optional) Duplicate the dataframe
dd = d
